# %% [markdown]
# ## Tokenization
#
# - Corpus - Paragraph
# - Sentence - line
# - Vocabulary - unique words
# - Words - smallest unit

# %% [markdown]
# #### Mandate things
# - pip install nltk
# - import nltk
# - nltk.download('punkt_tab')

# %%
corpus = """
Hello, Myself Purvi jain! I am doing NLP course by Krish Naik.
"""

# %% [markdown]
# ### Pargarph ---> Sentence

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['\nHello, Myself Purvi jain!', 'I am doing NLP course by Krish Naik.']

# %% [markdown]
# ### Paragraph ---> Words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Myself',
#  'Purvi',
#  'jain',
#  '!',
#  'I',
#  'am',
#  'doing',
#  'NLP',
#  'course',
#  'by',
#  'Krish',
#  'Naik',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Myself',
#  'Purvi',
#  'jain',
#  '!',
#  'I',
#  'am',
#  'doing',
#  'NLP',
#  'course',
#  'by',
#  'Krish',
#  'Naik',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Myself',
#  'Purvi',
#  'jain',
#  '!',
#  'I',
#  'am',
#  'doing',
#  'NLP',
#  'course',
#  'by',
#  'Krish',
#  'Naik',
#  '.']
